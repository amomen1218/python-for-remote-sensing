# %% [markdown]
# <a href="https://colab.research.google.com/github/amomen1218/python-for-remote-sensing/blob/main/Coordinate_Reference_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
dc = gpd.read_file ("/Bangladesh_shp")
print (dc)
dc.plot(column="ADM1_EN", color='red', figsize=(10, 5), edgecolor="black", linewidth=0.5)
plt.title ("Bangladesh")
plt.show()
print("CRS: {}".format(dc.crs)) #Get CRS(coordinate reference system) for DC shapefile
# Out:
# /usr/local/lib/python3.10/dist-packages/pyogrio/geopandas.py:265: UserWarning: More than one layer found in 'Bangladesh_shp': 'bgd_admbnda_adm4_bbs_20201113' (default), 'bgd_admbndp_admALL_bbs_itos_20201113', 'bgd_admbnda_adm0_bbs_20201113', 'bgd_admbndl_admALL_bbs_itos_20201113', 'bgd_admbnda_adm2_bbs_20201113', 'bgd_admbnda_adm1_bbs_20201113', 'bgd_admbnda_adm3_bbs_20201113', 'bgd_admbndt_adminUnitLookup'. Specify layer parameter to avoid this warning.
#   result = read_func(
#       Shape_Leng  Shape_Area             ADM4_EN  ADM4_PCODE ADM4_REF  \
# 0       0.286382    0.001944             Abaipur  BD40448010     None
# 1       0.098597    0.000317         Abdullahpur  BD30599411     None
# 2       0.170051    0.001055          Abdullapur  BD10092513     None
# 3       0.055861    0.000172          Abdullapur  BD20153311     None
# 4       0.312536    0.002235            Abdulpur  BD40507916     None
# ...          ...         ...                 ...         ...      ...
# ...

# %%
from google.colab import drive #connetion to google drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-14-e88ec7b275ed> in <cell line: 2>()
#       1 from google.colab import drive #connetion to google drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
dc = gpd.read_file("/Bangladesh_shp")
# Example 1: Create a copy of the DC shapefile
dc_reproject = dc.copy()

# Example 1: Reproject the data to NAD83 using PROJ.4 string
# Source: https://spatialreference.org/ref/epsg/nad83/
dc_reproject = dc_reproject.to_crs("+proj=longlat +ellps=GRS80 +datum=NAD83 +no_defs")


# Example 2: Create a copy of the DC shapefile
dc_reproject_epsg = dc.copy()

# Example 2: Reproject the data to NAD83 using EPSG code
dc_reproject_epsg = dc_reproject_epsg.to_crs(epsg=4269)
# Example 1: Print new CRS of DC
print("Example 1 (PROJ.4 string) CRS: {}".format(dc_reproject.crs))

# Example 2: Print new CRS of DC
print("Example 2 (EPSG code) CRS: {}".format(dc_reproject_epsg.crs))
# Map original DC shapefile
dc.plot(column= "ADM1_EN", color='green', figsize=(10, 5), edgecolor="green", linewidth=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pyogrio/geopandas.py:265: UserWarning: More than one layer found in 'Bangladesh_shp': 'bgd_admbnda_adm4_bbs_20201113' (default), 'bgd_admbndp_admALL_bbs_itos_20201113', 'bgd_admbnda_adm0_bbs_20201113', 'bgd_admbndl_admALL_bbs_itos_20201113', 'bgd_admbnda_adm2_bbs_20201113', 'bgd_admbnda_adm1_bbs_20201113', 'bgd_admbnda_adm3_bbs_20201113', 'bgd_admbndt_adminUnitLookup'. Specify layer parameter to avoid this warning.
#   result = read_func(
# Example 1 (PROJ.4 string) CRS: +proj=longlat +ellps=GRS80 +datum=NAD83 +no_defs +type=crs
# Example 2 (EPSG code) CRS: EPSG:4269
# <ipython-input-41-ffb2604fb71a>:23: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   dc.plot(column= "ADM1_EN", color='green', figsize=(10, 5), edgecolor="green", linewidth=0.5)
