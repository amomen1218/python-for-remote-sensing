# %%
# !pip install numpy

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
values = np.random.randn(100)
plt.plot(values)
plt.show()

# %%
np.sqrt(4)
# Out:
# 2.0

# %%
np.log(4)
# Out:
# 1.3862943611198906

# %%
np.cos(4)
# Out:
# -0.6536436208636119
